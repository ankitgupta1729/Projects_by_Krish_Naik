# %%
from platform import python_version
python_version()
# Out:
# '3.6.13'

# %%
import os
os.getcwd()
# Out:
# "c:\\Users\\ankit19.gupta\\Desktop\\Self Projects\\4. Artificial Neural Network for Customer's Exit Prediction from Bank"

# %%
## Here we will predict whether customers of a bank will leave a bank in future or not based on the information
## credit score or number of products taken by the bank
## we will use a classification algorithm to know whether a customer leave a bank or not in future or not

# %% [markdown]
# ### Part 1 - Data Preprocessing

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('BankCustomers.csv')

# %%
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
## exited column contains past information whether in past he has left the bank or not.
## hascrcard column denotes whether customer has credit card or not
X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, 13]

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
## convert categorical feature into dummy variables
## if there are three classes in geography, then we assign 000,001,... to them for each combination and drop the first because
## we don't need the first class, we can understand whether first class is there or not by other two classes
## for gender, male and female are two classes..we drop the female class because we can get it by male class..if male=0
## then it means female is there otherwise not 

states=pd.get_dummies(dataset['Geography'],drop_first=True)
gender=pd.get_dummies(dataset['Gender'],drop_first=True)

# %%
states
# Out:
#       Germany  Spain
# 0           0      0
# 1           0      1
# 2           0      0
# 3           0      0
# 4           0      1
# ...       ...    ...
# 9995        0      0
# 9996        0      0
# 9997        0      0
# 9998        1      0
# 9999        0      0
#
# [10000 rows x 2 columns]

# %%
gender
# Out:
#       Male
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 9995     1
# 9996     1
# 9997     0
# 9998     1
# 9999     0
#
# [10000 rows x 1 columns]

# %%
#drop the columns as it is no longer required

X=X.drop(['Geography','Gender'],axis=1)

# %%
X
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary
# 0                  1        101348.88
# 1                  1        112542.58
# ...

# %%
#concatenate the remaining dummies columns
X=pd.concat([X,states,gender],axis=1)

# %%
X
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0                  1        101348.88        0      0     0
# ...

# %%
X
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0                  1        101348.88        0      0     0
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
X_train
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 7389          667   34       5       0.00              2          1
# 9275          427   42       1   75681.52              1          1
# 2995          535   29       2  112367.34              1          1
# 5316          654   40       5  105683.63              1          1
# 356           850   57       8  126776.30              2          1
# ...           ...  ...     ...        ...            ...        ...
# 9225          594   32       4  120074.97              2          1
# 4859          794   22       4  114440.24              1          1
# 3264          738   35       5  161274.05              2          1
# 9845          590   38       9       0.00              2          1
# 2732          623   48       1  108076.33              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 7389               0        163830.64        0      1     0
# ...

# %%
X_test
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 9394          597   35       8  131101.04              1          1
# 898           523   40       2  102967.41              1          1
# 2398          706   42       8   95386.82              1          1
# 5906          788   32       4  112079.58              1          0
# 2343          706   38       5  163034.82              2          1
# ...           ...  ...     ...        ...            ...        ...
# 1037          625   24       1       0.00              2          1
# 2899          586   35       7       0.00              2          1
# 9549          578   36       1  157267.95              2          1
# 2740          650   34       4  142393.11              1          1
# 6690          573   30       8  127406.50              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 9394               1        192852.67        1      0     0
# ...

# %%
y_train
# Out:
# 7389    0
# 9275    0
# 2995    0
# 5316    0
# 356     0
#        ..
# 9225    0
# 4859    0
# 3264    0
# 9845    0
# 2732    1
# Name: Exited, Length: 8000, dtype: int64

# %%
y_test
# Out:
# 9394    0
# 898     1
# 2398    0
# 5906    0
# 2343    0
#        ..
# 1037    0
# 2899    0
# 9549    0
# 2740    0
# 6690    0
# Name: Exited, Length: 2000, dtype: int64

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.16958176, -0.46460796,  0.00666099, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-2.30455945,  0.30102557, -1.37744033, ...,  1.75486502,
#         -0.57369368,  0.91601335],
#        [-1.19119591, -0.94312892, -1.031415  , ..., -0.5698444 ,
#         -0.57369368, -1.09168714],
#        ...,
#        [ 0.9015152 , -0.36890377,  0.00666099, ..., -0.5698444 ,
#         -0.57369368,  0.91601335],
#        [-0.62420521, -0.08179119,  1.39076231, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-0.28401079,  0.87525072, -1.37744033, ...,  1.75486502,
#         -0.57369368, -1.09168714]])

# %%
X_test
# Out:
# array([[-0.55204276, -0.36890377,  1.04473698, ...,  1.75486502,
#         -0.57369368, -1.09168714],
#        [-1.31490297,  0.10961719, -1.031415  , ..., -0.5698444 ,
#         -0.57369368, -1.09168714],
#        [ 0.57162971,  0.30102557,  1.04473698, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        ...,
#        [-0.74791227, -0.27319958, -1.37744033, ..., -0.5698444 ,
#          1.74309049,  0.91601335],
#        [-0.00566991, -0.46460796, -0.33936434, ...,  1.75486502,
#         -0.57369368,  0.91601335],
#        [-0.79945688, -0.84742473,  1.04473698, ...,  1.75486502,
#         -0.57369368,  0.91601335]])

# %% [markdown]
# ### Part 2 - Now let's make the ANN!

# %%
# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense

# Initialising the ANN
classifier = Sequential()

# %%
## Adding the input layer and the first hidden layer
## "uniform" means weights are initialized 0 to 1.
## input neurons(features) are 11 and output neurons are 6 (just making ann in this way) and output function is relu
## to make output between 0 and 1
classifier.add(Dense(activation="relu", input_dim=11, units=6, kernel_initializer="uniform"))

# %%
# Adding the second hidden layer
classifier.add(Dense(activation="relu", units=6, kernel_initializer="uniform"))

# Adding the output layer
classifier.add(Dense(activation="sigmoid", units=1, kernel_initializer="uniform"))

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 6)                 72
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 7
# ...
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________

# %%
## Compiling the ANN
## if we have more classes to classify then we can use categoricall_crossentropy 
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
## batch_size =10 means we are taking 10 different inputs

# %%
# Fitting the ANN to the Training set
# epoch means combination of forward and backward propagation
classifier.fit(X_train, y_train, batch_size = 10, epochs = 50)
# Out:
# Epoch 1/50
# 800/800 [==============================] - 4s 1ms/step - loss: 0.4815 - accuracy: 0.7954
# Epoch 2/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4286 - accuracy: 0.7960
# Epoch 3/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4231 - accuracy: 0.7960
# Epoch 4/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4187 - accuracy: 0.8200
# Epoch 5/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4161 - accuracy: 0.8269
# Epoch 6/50
# 800/800 [==============================] - 1s 948us/step - loss: 0.4148 - accuracy: 0.8292
# Epoch 7/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4133 - accuracy: 0.8324
# Epoch 8/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4118 - accuracy: 0.8338
# Epoch 9/50
# 800/800 [==============================] - 1s 953us/step - loss: 0.4105 - accuracy: 0.8331
# Epoch 10/50
# ...

# %% [markdown]
# ### Part 3 - Making the predictions and evaluating the model

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix,accuracy_score
cm = confusion_matrix(y_test, y_pred)
accuracy=accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.8425
